# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torchvision import datasets,transforms
import matplotlib.pyplot as plt
import numpy as np

# %%
# 定义超参数
input_size = 28  #图像的总尺寸28*28
num_classes = 10  #标签的种类数
num_epochs = 3  #训练的总循环周期
batch_size = 64  #一个撮（批次）的大小，64张图片

# 训练集
train_dataset = datasets.MNIST(root='./data',
                            train=True,
                            transform=transforms.ToTensor(),
                            download=True)

# 测试集
test_dataset = datasets.MNIST(root='./data',
                           train=False,
                           transform=transforms.ToTensor())

# 构建batch数据
train_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                           batch_size=batch_size,
                                           shuffle=True)  # shuffle=True设置打乱数据集
test_loader = torch.utils.data.DataLoader(dataset=test_dataset,
                                           batch_size=batch_size,
                                           shuffle=True)

# %%
train_loader.dataset
# Out:
# Dataset MNIST
#     Number of datapoints: 60000
#     Root location: ./data
#     Split: Train
#     StandardTransform
# Transform: ToTensor()

# %%
test_loader.dataset
# Out:
# Dataset MNIST
#     Number of datapoints: 10000
#     Root location: ./data
#     Split: Test
#     StandardTransform
# Transform: ToTensor()

# %%
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Sequential(         # 输入大小 (1, 28, 28)
            nn.Conv2d(
                in_channels=1,              # 灰度图
                out_channels=16,            # 要得到几多少个特征图
                kernel_size=5,              # 卷积核大小
                stride=1,                   # 步长
                padding=2,                  # 如果希望卷积后大小跟原来一样，需要设置padding=(kernel_size-1)/2 if stride=1
            ),                              # 输出的特征图为 (16, 28, 28)
            nn.ReLU(),                      # relu层
            nn.MaxPool2d(kernel_size=2),    # 进行池化操作（2x2 区域）, 输出结果为： (16, 14, 14)
        )
        self.conv2 = nn.Sequential(         # 下一个套餐的输入 (16, 14, 14)
            nn.Conv2d(16, 32, 5, 1, 2),     # 输出 (32, 14, 14)
            nn.ReLU(),                      # relu层
            nn.MaxPool2d(2),                # 输出 (32, 7, 7)
        )
        self.out = nn.Linear(32 * 7 * 7, 10)   # 全连接层得到的结果

    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = x.view(x.size(0), -1)           # flatten操作，结果为：(batch_size, 32 * 7 * 7)
        output_ = self.out(x)
        return output_

# %%
sign = 1
def accuracy(predictions, labels):
    global sign
    if sign:
        print(torch.max(predictions.data, 1))  # [0]是values, [1]是indices
        sign = 0
    pred = torch.max(predictions.data, 1)[1]
    rights = pred.eq(labels.data.view_as(pred)).sum()
    return rights, len(labels)

# %%
# 实例化
net = CNN()
#损失函数
criterion = nn.CrossEntropyLoss()
#优化器
optimizer = optim.Adam(net.parameters(), lr=0.001) #定义优化器

sign_1 = 1
#开始训练循环
for epoch in range(num_epochs):
    #当前epoch的结果保存下来
    train_rights = []

    for batch_idx, (data, target) in enumerate(train_loader):  #针对容器中的每一个批进行循环, enumerate为枚举对象增加索引
        net.train()  # 设置训练模式
        output = net(data)
        global sign_1
        if sign_1:
            print(output)
            sign_1 = 0
        loss = criterion(output, target)
        optimizer.zero_grad()  # 清空过往梯度
        loss.backward()  # 反向传播, 计算当前梯度
        optimizer.step()  # 根据梯度更新网络参数
        right = accuracy(output, target)
        train_rights.append(right)


        if batch_idx % 100 == 0:

            net.eval()  # 设置评估模式
            val_rights = []

            for (data, target) in test_loader:
                output = net(data)
                right = accuracy(output, target)
                val_rights.append(right)

            #准确率计算
            train_r = (sum([tup[0] for tup in train_rights]), sum([tup[1] for tup in train_rights]))
            val_r = (sum([tup[0] for tup in val_rights]), sum([tup[1] for tup in val_rights]))

            print('当前epoch: {} [{}/{} ({:.0f}%)]\t损失: {:.6f}\t训练集准确率: {:.2f}%\t测试集正确率: {:.2f}%'.format(
                epoch,
                batch_idx * batch_size,
                len(train_loader.dataset),
                100. * batch_idx / len(train_loader),
                loss
#           1.7072e-01, -4.3311e-02, -1.7568e-02, -8.0253e-02, -1.1697e-02],
#         [ 4.9782e-03,  4.6347e-02,  1.8205e-02,  1.4274e-01,  8.0814e-02,
#           1.3191e-01, -5.7948e-02, -3.1839e-02, -4.7548e-02, -2.0517e-02],
#         [-3.9533e-02,  3.1208e-02,  1.5883e-02,  1.4301e-01,  7.7371e-02,
#           9.8664e-02, -5.2000e-02, -2.6862e-02, -2.6653e-02, -1.1616e-02],
#         [ 2.2515e-02, -1.1541e-03, -8.7534e-03,  1.4011e-01,  9.6598e-02,
#           1.5945e-01, -3.3190e-02, -9.5416e-03, -1.1299e-01,  7.7131e-03],
#         [ 3.4100e-02,  5.9934e-02,  1.5165e-02,  1.4339e-01,  8.8802e-02,
#           9.7936e-02, -4.1087e-02, -7.3701e-02, -3.3158e-02, -2.1518e-02],
#         [ 5.6003e-03,  7.4352e-02,  1.7532e-03,  1.5276e-01,  5.1131e-02,
#           1.2735e-01, -4.3436e-02, -2.8948e-02, -6.8376e-02, -1.3995e-02],
#         [ 1.4100e-02,  2.1971e-02, -6.4869e-02,  1.6200e-01,  1.2221e-01,
#           1.6109e-01,  5.9076e-02, -5.7542e-02, -1.5029e-01, -1.8107e-02],
#         [ 1.3778e-02,  6.1649e-02,  1.4116e-02,  1.4365e-01,  7.6004e-02,
#           1.0322e-01, -3.6849e-02, -4.4070e-02, -6.8525e-02, -2.1977e-02],
#         [-2.3040e-02,  3.6426e-02,  2.3399e-02,  1.4559e-01,  1.1138e-01,
#           1.5129e-01, -5.8580e-02, -4.1038e-02, -4.0854e-02, -7.0061e-03],
#         [ 1.0889e-02,  3.6076e-02,  4.9149e-02,  1.7262e-01,  1.0144e-01,
#           1.6312e-01, -7.0331e-02, -3.6840e-02, -9.7528e-02, -5.9411e-03],
#         [ 2.5660e-02,  5.3059e-02, -8.8511e-03,  1.4958e-01,  6.8911e-02,
#           1.0575e-01, -3.1046e-02, -4.2300e-02, -3.2010e-02, -2.9682e-02],
#         [-3.2550e-02,  5.4556e-02,  3.0155e-02,  1.2413e-01,  6.1352e-02,
#           1.4858e-01, -2.9696e-02, -2.3000e-02, -1.0098e-01,  6.4391e-03]],
#        grad_fn=<AddmmBackward0>)
# 当前epoch: 0 [0/60000 (0%)]	损失: 2.300177	训练集准确率: 6.25%	测试集正确率: 10.62%
# 当前epoch: 0 [6400/60000 (11%)]	损失: 0.386226	训练集准确率: 75.84%	测试集正确率: 92.17%
# 当前epoch: 0 [12800/60000 (21%)]	损失: 0.121128	训练集准确率: 84.23%	测试集正确率: 94.61%
# 当前epoch: 0 [19200/60000 (32%)]	损失: 0.068956	训练集准确率: 87.99%	测试集正确率: 95.39%
# 当前epoch: 0 [25600/60000 (43%)]	损失: 0.105064	训练集准确率: 90.15%	测试集正确率: 96.76%
# 当前epoch: 0 [32000/60000 (53%)]	损失: 0.076142	训练集准确率: 91.40%	测试集正确率: 96.99%
# 当前epoch: 0 [38400/60000 (64%)]	损失: 0.094250	训练集准确率: 92.36%	测试集正确率: 97.51%
# 当前epoch: 0 [44800/60000 (75%)]	损失: 0.176273	训练集准确率: 93.05%	测试集正确率: 97.71%
# 当前epoch: 0 [51200/60000 (85%)]	损失: 0.081346	训练集准确率: 93.59%	测试集正确率: 97.21%
# 当前epoch: 0 [57600/60000 (96%)]	损失: 0.011671	训练集准确率: 94.04%	测试集正确率: 97.90%
# 当前epoch: 1 [0/60000 (0%)]	损失: 0.062981	训练集准确率: 98.44%	测试集正确率: 98.04%
# 当前epoch: 1 [6400/60000 (11%)]	损失: 0.042567	训练集准确率: 97.91%	测试集正确率: 98.07%
# 当前epoch: 1 [12800/60000 (21%)]	损失: 0.069462	训练集准确率: 97.98%	测试集正确率: 97.86%
# 当前epoch: 1 [19200/60000 (32%)]	损失: 0.123603	训练集准确率: 98.03%	测试集正确率: 98.34%
# 当前epoch: 1 [25600/60000 (43%)]	损失: 0.023254	训练集准确率: 98.03%	测试集正确率: 98.17%
# 当前epoch: 1 [32000/60000 (53%)]	损失: 0.143850	训练集准确率: 98.05%	测试集正确率: 98.17%
# 当前epoch: 1 [38400/60000 (64%)]	损失: 0.143025	训练集准确率: 98.10%	测试集正确率: 98.49%
# 当前epoch: 1 [44800/60000 (75%)]	损失: 0.006568	训练集准确率: 98.06%	测试集正确率: 98.39%
# 当前epoch: 1 [51200/60000 (85%)]	损失: 0.021497	训练集准确率: 98.09%	测试集正确率: 98.60%
# 当前epoch: 1 [57600/60000 (96%)]	损失: 0.037444	训练集准确率: 98.13%	测试集正确率: 98.48%
# 当前epoch: 2 [0/60000 (0%)]	损失: 0.010467	训练集准确率: 100.00%	测试集正确率: 98.57%
# 当前epoch: 2 [6400/60000 (11%)]	损失: 0.018750	训练集准确率: 98.64%	测试集正确率: 98.65%
# 当前epoch: 2 [12800/60000 (21%)]	损失: 0.037514	训练集准确率: 98.60%	测试集正确率: 98.43%
# 当前epoch: 2 [19200/60000 (32%)]	损失: 0.098534	训练集准确率: 98.66%	测试集正确率: 98.79%
# 当前epoch: 2 [25600/60000 (43%)]	损失: 0.022703	训练集准确率: 98.61%	测试集正确率: 98.47%
# 当前epoch: 2 [32000/60000 (53%)]	损失: 0.018561	训练集准确率: 98.62%	测试集正确率: 98.68%
# 当前epoch: 2 [38400/60000 (64%)]	损失: 0.018920	训练集准确率: 98.64%	测试集正确率: 98.96%
# 当前epoch: 2 [44800/60000 (75%)]	损失: 0.006452	训练集准确率: 98.64%	测试集正确率: 98.98%
# 当前epoch: 2 [51200/60000 (85%)]	损失: 0.045395	训练集准确率: 98.67%	测试集正确率: 98.82%
# 当前epoch: 2 [57600/60000 (96%)]	损失: 0.013264	训练集准确率: 98.68%	测试集正确率: 99.06%

# %%
x = torch.tensor([1., 2.], requires_grad=True)
# x: tensor([1., 2.], requires_grad=True)
y = 100*x
# y: tensor([100., 200.], grad_fn=<MulBackward0>)

loss = y.sum()  # tensor(300., grad_fn=<SumBackward0>)

# Compute gradients of the parameters respect to the loss
print(x.grad)     # None, 反向传播前，梯度不存在
loss.backward()
print(x.grad)     # tensor([100., 100.]) loss对y的梯度为1， 对x的梯度为100

optim = torch.optim.SGD([x], lr=0.001) # 随机梯度下降， 学习率0.001
print(x)        # tensor([1., 2.], requires_grad=True)
optim.step()  # 更新x
print(x)        # tensor([0.9000, 1.9000], requires_grad=True) 变化量=梯度X学习率 0.1=100*0.001
# Out:
# None
# tensor([100., 100.])
# tensor([1., 2.], requires_grad=True)
# tensor([0.9000, 1.9000], requires_grad=True)
